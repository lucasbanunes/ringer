# %% [markdown]
# # Set references for v10 tuning and export to ONNX
#
# This notebook is dedicated to apply the linear correction in the neural network output w.r.t the avgmu and export the v9 best models to ONNX/keras format. Usually, keras versions is used into the prometheus framework. The ONNX version will be used into the athena framework.
#
# **NOTE**: ONNX is a Microsoft API for inference.
#
# **NOTE**: We will export all tunings from v10 r2 derivation

# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = '-1'
from kolmov import crossval_table, get_color_fader, fit_table
#import saphyra
import numpy as np
import pandas as pd
import collections
import matplotlib
import matplotlib.pyplot as plt
from pprint import pprint
# %config InlineBackend.figure_format = 'retina'
# Out:
# Welcome to JupyROOT 6.16/00
# Using all sub packages with ROOT dependence

# %%
def create_op_dict(op):
    d = {
              op+'_pd_ref'    : "reference/"+op+"_cutbased/pd_ref#0",
              op+'_fa_ref'    : "reference/"+op+"_cutbased/fa_ref#0",
              op+'_sp_ref'    : "reference/"+op+"_cutbased/sp_ref",
              op+'_pd_val'    : "reference/"+op+"_cutbased/pd_val#0",
              op+'_fa_val'    : "reference/"+op+"_cutbased/fa_val#0",
              op+'_sp_val'    : "reference/"+op+"_cutbased/sp_val",
              op+'_pd_op'     : "reference/"+op+"_cutbased/pd_op#0",
              op+'_fa_op'     : "reference/"+op+"_cutbased/fa_op#0",
              op+'_sp_op'     : "reference/"+op+"_cutbased/sp_op",

              # Counts
              op+'_pd_ref_passed'    : "reference/"+op+"_cutbased/pd_ref#1",
              op+'_fa_ref_passed'    : "reference/"+op+"_cutbased/fa_ref#1",
              op+'_pd_ref_total'     : "reference/"+op+"_cutbased/pd_ref#2",
              op+'_fa_ref_total'     : "reference/"+op+"_cutbased/fa_ref#2",
              op+'_pd_val_passed'    : "reference/"+op+"_cutbased/pd_val#1",
              op+'_fa_val_passed'    : "reference/"+op+"_cutbased/fa_val#1",
              op+'_pd_val_total'     : "reference/"+op+"_cutbased/pd_val#2",
              op+'_fa_val_total'     : "reference/"+op+"_cutbased/fa_val#2",
              op+'_pd_op_passed'     : "reference/"+op+"_cutbased/pd_op#1",
              op+'_fa_op_passed'     : "reference/"+op+"_cutbased/fa_op#1",
              op+'_pd_op_total'      : "reference/"+op+"_cutbased/pd_op#2",
              op+'_fa_op_total'      : "reference/"+op+"_cutbased/fa_op#2",
    }
    return d

tuned_info = collections.OrderedDict( {
              # validation
              "max_sp_val"      : 'summary/max_sp_val',
              "max_sp_pd_val"   : 'summary/max_sp_pd_val#0',
              "max_sp_fa_val"   : 'summary/max_sp_fa_val#0',
              # Operation
              "max_sp_op"       : 'summary/max_sp_op',
              "max_sp_pd_op"    : 'summary/max_sp_pd_op#0',
              "max_sp_fa_op"    : 'summary/max_sp_fa_op#0',
              } )

tuned_info.update(create_op_dict('tight'))
tuned_info.update(create_op_dict('medium'))
tuned_info.update(create_op_dict('loose'))
tuned_info.update(create_op_dict('vloose'))

# %%
def create_op_dict(op):
    
    d = collections.OrderedDict( {
              # validation
              "max_sp_val"      : 'summary/max_sp_val',
              "max_sp_pd_val"   : 'summary/max_sp_pd_val#0',
              "max_sp_fa_val"   : 'summary/max_sp_fa_val#0',
              # Operation
              "max_sp_op"       : 'summary/max_sp_op',
              "max_sp_pd_op"    : 'summary/max_sp_pd_op#0',
              "max_sp_fa_op"    : 'summary/max_sp_fa_op#0',
              
              # op
              'pd_ref'    : "reference/"+op+"/pd_ref#0",
              'fa_ref'    : "reference/"+op+"/fa_ref#0",
              'sp_ref'    : "reference/"+op+"/sp_ref",
              'pd_val'    : "reference/"+op+"/pd_val#0",
              'fa_val'    : "reference/"+op+"/fa_val#0",
              'sp_val'    : "reference/"+op+"/sp_val",
              'pd_op'     : "reference/"+op+"/pd_op#0",
              'fa_op'     : "reference/"+op+"/fa_op#0",
              'sp_op'     : "reference/"+op+"/sp_op",

              # Counts
              'pd_ref_passed'    : "reference/"+op+"/pd_ref#1",
              'fa_ref_passed'    : "reference/"+op+"/fa_ref#1",
              'pd_ref_total'     : "reference/"+op+"/pd_ref#2",
              'fa_ref_total'     : "reference/"+op+"/fa_ref#2",
              'pd_val_passed'    : "reference/"+op+"/pd_val#1",
              'fa_val_passed'    : "reference/"+op+"/fa_val#1",
              'pd_val_total'     : "reference/"+op+"/pd_val#2",
              'fa_val_total'     : "reference/"+op+"/fa_val#2",
              'pd_op_passed'     : "reference/"+op+"/pd_op#1",
              'fa_op_passed'     : "reference/"+op+"/fa_op#1",
              'pd_op_total'      : "reference/"+op+"/pd_op#2",
              'fa_op_total'      : "reference/"+op+"/fa_op#2",
    })
    return d


#op_names = ['tight_cutbased', 'medium_cutbased', 'loose_cutbased', 'vloose_cutbased']

#tuned_info = collections.OrderedDict({})
#for op in op_names:
#    tuned_info[op] = create_op_dict(op)

# %%
etbins = [15, 20, 30, 40, 50, 1000000]
etabins = [0.0, 0.8, 1.37, 1.54, 2.37, 2.50]
#etbins = [50, 10000000]
#etabins = [0.0, 0.8]

# %% [markdown]
# ## 1) Reading all tunings:

# %%
cv  = crossval_table( tuned_info, etbins = etbins , etabins = etabins )

# %%
cv.fill('/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/output/**/*.gz',
        'v20')
# Out:
# 2022-07-14 10:17:07,980 | Py.crossval_table                       INFO Reading file for v20 tag from /home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/output/**/*.gz
# 2022-07-14 10:17:07,981 | Py.crossval_table                       INFO There are 2500 files for this task...
# 2022-07-14 10:17:07,981 | Py.crossval_table                       INFO Filling the table...
# 2022-07-14 10:19:16,280 | Py.crossval_table                       INFO End of fill step, a pandas DataFrame was created...

# %%
cv.table()
# Out:
#      train_tag  et_bin  eta_bin  model_idx  sort  init  \
# 0          v20       3        1          0     0     0
# 1          v20       3        1          0     0     1
# 2          v20       3        1          0     0     2
# 3          v20       3        1          0     0     3
# 4          v20       3        1          0     0     4
# ...        ...     ...      ...        ...   ...   ...
# 2495       v20       2        4          0     9     5
# 2496       v20       2        4          0     9     6
# 2497       v20       2        4          0     9     7
# 2498       v20       2        4          0     9     8
# 2499       v20       2        4          0     9     9
#
#                                               file_name  tuned_idx  \
# 0     /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1     /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2     /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 3     /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 4     /home/lbarranunes/workspace/ringer_tunings/ver...          0
# ...                                                 ...        ...
# 2495  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2496  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2497  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2498  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2499  /home/lbarranunes/workspace/ringer_tunings/ver...          0
#
#       max_sp_val  max_sp_pd_val  ...  vloose_pd_ref_total  \
# 0       0.991214       0.995535  ...              2837736
# 1       0.991146       0.996564  ...              2837736
# 2       0.990267       0.995785  ...              2837736
# 3       0.991193       0.995045  ...              2837736
# 4       0.991409       0.995659  ...              2837736
# ...          ...            ...  ...                  ...
# 2495    0.981181       0.990023  ...               164380
# 2496    0.980942       0.991970  ...               164380
# 2497    0.980528       0.990327  ...               164380
# 2498    0.981323       0.991118  ...               164380
# 2499    0.981109       0.989476  ...               164380
#
#       vloose_fa_ref_total  vloose_pd_val_passed  vloose_fa_val_passed  \
# 0                  112229                283698                   432
# 1                  112229                283698                   426
# 2                  112229                283698                   538
# 3                  112229                283698                   426
# 4                  112229                283698                   432
# ...                   ...                   ...                   ...
# 2495                24980                 15912                    51
# 2496                24980                 15919                    50
# 2497                24980                 15942                    50
# 2498                24980                 15856                    52
# 2499                24980                 15902                    50
#
#       vloose_pd_val_total  vloose_fa_val_total  vloose_pd_op_passed  \
# 0                  283774                11223              2836979
# 1                  283774                11223              2836979
# 2                  283774                11223              2836979
# 3                  283774                11223              2836979
# 4                  283774                11223              2836980
# ...                   ...                  ...                  ...
# 2495                16438                 2498               158966
# 2496                16438                 2498               158973
# 2497                16438                 2498               158959
# 2498                16438                 2498               158960
# 2499                16438                 2498               158977
#
#       vloose_fa_op_passed  vloose_pd_op_total  vloose_fa_op_total
# 0                    3546             2837736              112229
# 1                    3544             2837736              112229
# 2                    4567             2837736              112229
# 3                    3474             2837736              112229
# 4                    3520             2837736              112229
# ...                   ...                 ...                 ...
# 2495                  584              164380               24980
# 2496                  570              164380               24980
# 2497                  588              164380               24980
# 2498                  582              164380               24980
# 2499                  579              164380               24980
#
# [2500 rows x 98 columns]

# %% [markdown]
# ### 1.1) Get best inits and sorts:

# %%
best_inits = cv.filter_inits("max_sp_val")
best_sorts = cv.filter_sorts( best_inits , 'max_sp_op')

# %%
best_inits
# Out:
#      train_tag  et_bin  eta_bin  model_idx  sort  init  \
# 1504       v20       0        0          0     0     4
# 1519       v20       0        0          0     1     9
# 1527       v20       0        0          0     2     7
# 1536       v20       0        0          0     3     6
# 1544       v20       0        0          0     4     4
# ...        ...     ...      ...        ...   ...   ...
# 2150       v20       4        4          0     5     0
# 2161       v20       4        4          0     6     1
# 2179       v20       4        4          0     7     9
# 2184       v20       4        4          0     8     4
# 2198       v20       4        4          0     9     8
#
#                                               file_name  tuned_idx  \
# 1504  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1519  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1527  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1536  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1544  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# ...                                                 ...        ...
# 2150  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2161  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2179  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2184  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2198  /home/lbarranunes/workspace/ringer_tunings/ver...          0
#
#       max_sp_val  max_sp_pd_val  ...  vloose_pd_ref_total  \
# 1504    0.980932       0.985912  ...               232819
# 1519    0.979152       0.985396  ...               232819
# 1527    0.978237       0.985439  ...               232819
# 1536    0.978632       0.983764  ...               232819
# 1544    0.980430       0.986728  ...               232819
# ...          ...            ...  ...                  ...
# 2150    0.993277       0.997438  ...                89786
# 2161    0.991556       0.996881  ...                89786
# 2179    0.992174       0.995656  ...                89786
# 2184    0.992653       0.998329  ...                89786
# 2198    0.991509       0.997215  ...                89786
#
#       vloose_fa_ref_total  vloose_pd_val_passed  vloose_fa_val_passed  \
# 1504               187639                 23017                   525
# 1519               187639                 23015                   597
# 1527               187639                 23015                   641
# 1536               187639                 23015                   637
# 1544               187639                 23015                   531
# ...                   ...                   ...                   ...
# 2150                93785                  8625                    44
# 2161                93785                  8625                    56
# 2179                93785                  8621                    45
# 2184                93785                  8612                    48
# 2198                93785                  8625                    65
#
#       vloose_pd_val_total  vloose_fa_val_total  vloose_pd_op_passed  \
# 1504                23282                18764               230153
# 1519                23282                18764               230153
# 1527                23282                18764               230153
# 1536                23282                18764               230153
# 1544                23282                18764               230151
# ...                   ...                  ...                  ...
# 2150                 8979                 9378                86202
# 2161                 8978                 9379                86230
# 2179                 8978                 9379                86180
# 2184                 8978                 9379                86212
# 2198                 8978                 9379                86235
#
#       vloose_fa_op_passed  vloose_pd_op_total  vloose_fa_op_total
# 1504                 5309              232819              187639
# 1519                 5575              232819              187639
# 1527                 5402              232819              187639
# 1536                 5462              232819              187639
# 1544                 5351              232819              187639
# ...                   ...                 ...                 ...
# 2150                  484               89786               93785
# 2161                  569               89786               93785
# 2179                  488               89786               93785
# 2184                  538               89786               93785
# 2198                  536               89786               93785
#
# [250 rows x 98 columns]

# %%
best_sorts
# Out:
#      train_tag  et_bin  eta_bin  model_idx  sort  init  \
# 1570       v20       0        0          0     7     0
# 1818       v20       0        1          0     1     8
# 1644       v20       0        2          0     4     4
# 1711       v20       0        3          0     1     1
# 2005       v20       0        4          0     0     5
# 1078       v20       1        0          0     7     8
# 1474       v20       1        1          0     7     4
# 1169       v20       1        2          0     6     9
# 1313       v20       1        3          0     1     3
# 2356       v20       1        4          0     5     6
# 329        v20       2        0          0     2     9
# 1248       v20       2        1          0     4     8
# 1916       v20       2        2          0     1     6
# 460        v20       2        3          0     6     0
# 2485       v20       2        4          0     8     5
# 296        v20       3        0          0     9     6
# 34         v20       3        1          0     3     4
# 993        v20       3        2          0     9     3
# 716        v20       3        3          0     1     6
# 2271       v20       3        4          0     7     1
# 140        v20       4        0          0     4     0
# 574        v20       4        1          0     7     4
# 863        v20       4        2          0     6     3
# 661        v20       4        3          0     6     1
# 2115       v20       4        4          0     1     5
#
#                                               file_name  tuned_idx  \
# 1570  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1818  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1644  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1711  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2005  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1078  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1474  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1169  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1313  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2356  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 329   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1248  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 1916  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 460   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2485  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 296   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 34    /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 993   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 716   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2271  /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 140   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 574   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 863   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 661   /home/lbarranunes/workspace/ringer_tunings/ver...          0
# 2115  /home/lbarranunes/workspace/ringer_tunings/ver...          0
#
#       max_sp_val  max_sp_pd_val  ...  vloose_pd_ref_total  \
# 1570    0.979604       0.983893  ...               232819
# 1818    0.971438       0.981773  ...               141000
# 1644    0.947048       0.951716  ...                51566
# 1711    0.970319       0.983638  ...               227345
# 2005    0.953923       0.958794  ...                19893
# 1078    0.987460       0.991449  ...              1499273
# 1474    0.981570       0.988858  ...               896615
# 1169    0.968573       0.980116  ...               283647
# 1313    0.978887       0.987757  ...              1132030
# 2356    0.970039       0.984533  ...                84054
# 329     0.992703       0.995908  ...              4188536
# 1248    0.989491       0.994282  ...              2539137
# 1916    0.980898       0.983676  ...               645043
# 460     0.986878       0.992684  ...              2377013
# 2485    0.979714       0.992335  ...               164380
# 296     0.994383       0.997638  ...              4627778
# 34      0.991312       0.996448  ...              2837736
# 993     0.986416       0.989339  ...               470869
# 716     0.989620       0.993755  ...              2429079
# 2271    0.985844       0.996591  ...               187729
# 140     0.998609       0.999206  ...              1699541
# 574     0.997310       0.998500  ...              1059922
# 863     0.996281       0.996252  ...               170752
# 661     0.994028       0.996637  ...               901075
# 2115    0.993757       0.997438  ...                89786
#
#       vloose_fa_ref_total  vloose_pd_val_passed  vloose_fa_val_passed  \
# 1570               187639                 23016                   582
# 1818               143657                 13929                   722
# 1644                30037                  5033                   426
# 1711               205792                 22338                   868
# 2005                15512                  1862                    57
# 1078               316581                149174                   684
# 1474               227709                 89322                   956
# 1169                47550                 27418                   170
# 1313               307253                112713                  1313
# 2356                36522                  8048                   122
# 329                223869                418129                   359
# 1248               156992                253675                   503
# 1916                35206                 63149                    69
# 460                196711                237499                   716
# 2485                24980                 15908                    57
# 296                162421                462520                   264
# 34                 112229                283699                   368
# 993                 25449                 46074                    36
# 716                131668                242832                   465
# 2271                16100                 18209                    23
# 140               3769656                169913                  1984
# 574               2560472                105913                  1390
# 863                560953                 16843                   101
# 661               1318418                 90092                  5428
# 2115                93785                  8613                    41
#
#       vloose_pd_val_total  vloose_fa_val_total  vloose_pd_op_passed  \
# 1570                23282                18764               230152
# 1818                14100                14366               139283
# 1644                 5157                 3003                50324
# 1711                22735                20579               223378
# 2005                 1990                 1551                18613
# 1078               149927                31658              1491729
# 1474                89661                22771               893215
# 1169                28365                 4755               274277
# 1313               113203                30726              1127149
# 2356                 8405                 3653                80473
# 329                418854                22387              4181341
# 1248               253914                15699              2536748
# 1916                64505                 3520               631892
# 460                237701                19671              2374992
# 2485                16438                 2498               158976
# 296                462777                16242              4625216
# 34                 283774                11223              2836979
# 993                 47086                 2545               460897
# 716                242908                13167              2428321
# 2271                18773                 1610               182305
# 140                169954               376966              1699132
# 574                105992               256047              1059142
# 863                 17075                56095               168368
# 661                 90107               131842               900921
# 2115                 8979                 9378                86209
#
#       vloose_fa_op_passed  vloose_pd_op_total  vloose_fa_op_total
# 1570                 5249              232819              187639
# 1818                 6884              141000              143657
# 1644                 3880               51566               30037
# 1711                 7941              227345              205792
# 2005                  712               19893               15512
# 1078                 6471             1499273              316581
# 1474                 9189              896615              227709
# 1169                 1551              283647               47550
# 1313                12338             1132030              307253
# 2356                 1203               84054               36522
# 329                  3397             4188536              223869
# 1248                 5029             2539137              156992
# 1916                  738              645043               35206
# 460                  7269             2377013              196711
# 2485                  565              164380               24980
# 296                  2370             4627778              162421
# 34                   3376             2837736              112229
# 993                   400              470869               25449
# 716                  4469             2429079              131668
# 2271                  241              187729               16100
# 140                 16024             1699541             3769656
# 574                 13000             1059922             2560472
# 863                   774              170752              560953
# 661                 51232              901075             1318418
# 2115                  469               89786               93785
#
# [25 rows x 98 columns]

# %% [markdown]
# ### 1.2) Get best models:
#
# Get all best models for each bin. Expected to be 25 models.

# %%
best_models = cv.get_best_models(best_sorts, remove_last=True)
# Out:
# 2022-07-11 14:24:37.066406: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-07-11 14:24:37.066443: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: UNKNOWN ERROR (-1)
# 2022-07-11 14:24:37.066460: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (caloba51): /proc/driver/nvidia/version does not exist
# 2022-07-11 14:24:37.066703: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-11 14:24:37.099235: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2400000000 Hz
# 2022-07-11 14:24:37.106356: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x97aa770 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-07-11 14:24:37.106415: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
best_models[3][0].keys()
# Out:
# dict_keys(['model', 'etBin', 'etaBin', 'etBinIdx', 'etaBinIdx', 'history'])

# %% [markdown]
# ## 2) Linear correction:
#
# Here we will set all thresholds to operate as the same pd reference from cut-based using the pileup linear correction strategy. As the classifier efficiency has some "dependence" w.r.t the pileup we adopt the linear adjustment to "fix" the trigger efficiency. Here we will "fix" the neural network threshold w.r.t the pileup.
#
# ### 2.1) Get all PD/Fas values:
#
# Read all reference values from the storage.

# %%
# calculate all pd/fa from reference file
ref_path = '/home/lbarranunes/data/data17_13TeV.AllPeriods.sgn.probes_lhmedium_EGAM1.bkg.VProbes_EGAM7.GRL_v97/references/data17_13TeV.AllPeriods.sgn.probes_lhmedium_EGAM1.bkg.VProbes_EGAM7.GRL_v97_et{ET}_eta{ETA}.ref.pic.gz'
ref_paths = [[ ref_path.format(ET=et,ETA=eta) for eta in range(5)] for et in range(5)]
ref_matrix = [[ {} for eta in range(5)] for et in range(5)]
references = ['tight_cutbased', 'medium_cutbased' , 'loose_cutbased', 'vloose_cutbased']
from saphyra.core import ReferenceReader
for et_bin in range(5):
    for eta_bin in range(5):
        for name in references:
            refObj = ReferenceReader().load(ref_paths[et_bin][eta_bin])
            _pd = refObj.getSgnPassed(name)/refObj.getSgnTotal(name)
            fa = refObj.getBkgPassed(name)/refObj.getBkgTotal(name)
            ref_matrix[et_bin][eta_bin][name] = {'pd':_pd, 'fa':fa, 'pd_epsilon':0}


# calculate all pd/fa from reference file
#ref_paths = [[ ref_path.format(ET=et,ETA=eta) for eta in range(5)] for et in range(5)]
#ref_values = [[ {} for eta in range(5)] for et in range(5)]
#ref_matrix = [[ {} for eta in range(5)] for et in range(5)]
#references = ['tight_cutbased', 'medium_cutbased' , 'loose_cutbased', 'vloose_cutbased']


#from saphyra.core import ReferenceReader
#from Gaugi import load as gload
#for et_bin in range(5):
#    for eta_bin in range(5):
#        for op_name in op_names:
#            refObj = gload(ref_paths[et_bin][eta_bin])
            #_pd = refObj.getSgnPassed(op_name )/refObj.getSgnTotal(op_name)
#            _pd = refObj['sgnRef'][op_name]['passed']/refObj['sgnRef'][op_name]['total']
            #_fa = refObj.getBkgPassed(op_name )/refObj.getBkgTotal(op_name)
#            _fa = refObj['bkgRef'][op_name]['passed']/refObj['bkgRef'][op_name]['total']
#            ref_values[et_bin][eta_bin][op_name] = {'pd':_pd, 'fa':_fa, 'pd_epsilon':0.0}

# %% [markdown]
# ### 2.2) Create data generator:
#
# Since each tuning models is fed by a different data organization, we need to create a generator to open the data file, prepare the matrix and apply some pre-processing (if needed).

# %%
def generator( path ):
    def norm1( data ):
        norms = np.abs( data.sum(axis=1) )
        norms[norms==0] = 1
        return data/norms[:,None]
    from Gaugi import load
    d = load(path)
    feature_names = d['features'].tolist()

    # How many events?
    n = d['data'].shape[0]
    
    # extract rings
    data_rings = norm1(d['data'][:,1:101])
    target = d['target']
    avgmu = d['data'][:,0]
    
    return [data_rings], target, avgmu

# %%
path = '/home/lbarranunes/data/data17_13TeV.AllPeriods.sgn.probes_lhmedium_EGAM1.bkg.VProbes_EGAM7.GRL_v97/data17_13TeV.AllPeriods.sgn.probes_lhmedium_EGAM1.bkg.VProbes_EGAM7.GRL_v97_et{ET}_eta{ETA}.npz'
#[[ path.format(ET=et,ETA=eta) for eta in range(5)] for et in range(5)]
paths = [[ path.format(ET=et,ETA=eta) for eta in range(5)] for et in range(5)]

# %%
# create the table class
#ct  = fit_table( etbins , etabins)
ct  = fit_table( generator, etbins , etabins, 0.02, 0.5, 16, 60, xmin_percentage=0.05, xmax_percentage=99.95 )

# %% [markdown]
# ### 2.3) Apply linear correction:
#
# **NOTE**: Take about 25 minutes.

# %%
# Fill it
ct.fill(paths, best_models, ref_matrix, 'correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose')
# Out:
# Applying ATLAS style settings...
# Fitting... |############################################################| 25/25
# Fitting... ... finished task in 3106.979051s.
# 2022-07-11 09:11:24,545 | Py.fit_table                         WARNING Retrieved positive angular factor of the linear correction, setting to 0!
# 2022-07-11 09:12:09,416 | Py.fit_table                         WARNING Retrieved positive angular factor of the linear correction, setting to 0!
# 2022-07-11 09:14:23,553 | Py.fit_table                         WARNING Retrieved positive angular factor of the linear correction, setting to 0!
# 2022-07-11 09:14:41,990 | Py.fit_table                         WARNING Retrieved positive angular factor of the linear correction, setting to 0!
# 2022-07-11 09:15:00,661 | Py.fit_table                         WARNING Retrieved positive angular factor of the linear correction, setting to 0!
# 2022-07-11 09:15:19,345 | Py.fit_table                         WARNING Retrieved positive angular factor of the linear correction, setting to 0!

# %%
ct.table().head()
# Out:
#               name  et_bin  eta_bin  reference_signal_passed  \
# 0   tight_cutbased       0        0                   227619
# 1  medium_cutbased       0        0                   227780
# 2   loose_cutbased       0        0                   229996
# 3  vloose_cutbased       0        0                   230152
# 4   tight_cutbased       0        1                   137861
#
#    reference_signal_total  reference_signal_eff  reference_background_passed  \
# 0                  232819              0.977666                        23318
# 1                  232819              0.978360                        24336
# 2                  232819              0.987876                        31867
# 3                  232819              0.988548                        32748
# 4                  141000              0.977742                        31938
#
#    reference_background_total  reference_background_eff  signal_passed  ...  \
# 0                      187639                  0.124271         227545  ...
# 1                      187639                  0.129701         227723  ...
# 2                      187639                  0.169837         229959  ...
# 3                      187639                  0.174527         230117  ...
# 4                      143657                  0.222321         137816  ...
#
#    signal_eff  background_passed  background_total  background_eff  \
# 0    0.977347               3689            187639        0.019660
# 1    0.978112               3748            187639        0.019975
# 2    0.987716               5081            187639        0.027079
# 3    0.988394               5226            187639        0.027851
# 4    0.977418               5018            143657        0.034930
#
#    signal_corrected_passed  signal_corrected_total  signal_corrected_eff  \
# 0                   227541                  232819              0.977330
# 1                   227688                  232819              0.977961
# 2                   229971                  232819              0.987767
# 3                   230140                  232819              0.988493
# 4                   137797                  141000              0.977284
#
#    background_corrected_passed  background_corrected_total  \
# 0                         3601                      187639
# 1                         3662                      187639
# 2                         4994                      187639
# 3                         5139                      187639
# 4                         4891                      143657
#
#    background_corrected_eff
# 0                  0.019191
# 1                  0.019516
# 2                  0.026615
# 3                  0.027388
# 4                  0.034046
#
# [5 rows x 21 columns]

# %%
ct.table().to_csv('ct_table.csv')

# %% [markdown]
# ### 2.3) Create beamer report:

# %%
ct.dump_beamer_table(ct.table(), best_models, 'data17_13TeV v20 tuning', 
                                              'correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose.pdf')
# Out:
# 2022-07-11 09:17:12,485 | Py.BeamerTexReportTemplate1             INFO Started creating beamer file correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose.pdf latex code...
# This is pdfTeX, Version 3.14159265-2.6-1.40.18 (TeX Live 2017/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose.tex
# LaTeX2e <2017-04-15>
# Babel <3.18> and hyphenation patterns for 84 language(s) loaded.
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamer.cls
# Document Class: beamer 2018/02/20 v3.50 A class for typesetting presentations
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasemodes.sty
# (/usr/share/texlive/texmf-dist/tex/latex/etoolbox/etoolbox.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasedecode.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifpdf.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseoptions.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifvtex.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/ifxetex/ifxetex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/base/size11.clo)
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/basiclayer/pgfcore.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/systemlayer/pgfsys.sty
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/utilities/pgfrcs.sty
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-common.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-common-lists.t
# ex)) (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-latex.def
# (/usr/share/texlive/texmf-dist/tex/latex/ms/everyshi.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfrcs.code.tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfkeys.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfkeysfiltered.code.t
# ex)) (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgf.cfg)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys-pdftex.def
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys-common-pdf.de
# f)))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsyssoftpath.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsysprotocol.code.
# tex)) (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/colortbl/colortbl.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.styThis is pdfTeX, Version 3.14159265-2.6-1.40.18 (TeX Live 2017/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# ))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/svgnam.def)
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/x11nam.defentering extended mode
# (./correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose.tex
# LaTeX2e <2017-04-15>
# Babel <3.18> and hyphenation patterns for 84 language(s) loaded.
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamer.cls
# Document Class: beamer 2018/02/20 v3.50 A class for typesetting presentations
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasemodes.sty
# (/usr/share/texlive/texmf-dist/tex/latex/etoolbox/etoolbox.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasedecode.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifpdf.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseoptions.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifvtex.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/ifxetex/ifxetex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/base/size11.clo)
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/basiclayer/pgfcore.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/systemlayer/pgfsys.sty
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/utilities/pgfrcs.sty
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-common.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-common-lists.t
# ex)) (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-latex.def
# (/usr/share/texlive/texmf-dist/tex/latex/ms/everyshi.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfrcs.code.tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfkeys.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfkeysfiltered.code.t
# ex))))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcore.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmath.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathcalc.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathutil.code.tex (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgf.cfg))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys-pdftex.def
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathparser.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys-common-pdf.de
# f)))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsyssoftpath.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsysprotocol.code.
# tex))) (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.basic.code
# .tex
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.trigonomet
# ric.code.tex
# (/usr/share/texlive/texmf-dist/tex/latex/colortbl/colortbl.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.random.cod
# e.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.comparison
# .code.tex
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/svgnam.def)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.base.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.round.code
# .tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.misc.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.integerari
# thmetics.code.tex)))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfloat.code.tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepoints.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathconstruct.
# code.tex)
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/x11nam.def)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathusage.code
# .tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorescopes.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoregraphicstate.c
# ode.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoretransformation
# s.code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorequick.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreobjects.code.t
# ex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathprocessing
# .code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorearrows.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreshade.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreimage.code.tex
#
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreexternal.code.
# tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorelayers.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoretransparency.c
# ode.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepatterns.code.
# tex))) (/usr/share/texlive/texmf-dist/tex/latex/pgf/utilities/xxcolor.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/atbegshi.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/infwarerr.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ltxcmds.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/hyperref.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/hobsub-hyperref.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/hobsub-generic.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcore.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmath.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathcalc.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathutil.code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathparser.code.tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.basic.code
# .tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.trigonomet
# ric.code.tex
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/auxhook.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/kvoptions.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/pd1enc.def)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.random.cod
# e.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.comparison
# .code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.base.code.
# tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.round.code
# .tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.misc.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.integerari
# thmetics.code.tex)))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfloat.code.tex
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/hyperref.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/url/url.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepoints.code.te
# x))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathconstruct.
# code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathusage.code
# .tex
#
# Package hyperref Message: Stopped early.
#
# ) (/usr/share/texlive/texmf-dist/tex/latex/hyperref/hpdftex.def)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorescopes.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoregraphicstate.c
# ode.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoretransformation
# s.code.tex
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/rerunfilecheck.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorequick.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreobjects.code.t
# ex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathprocessing
# .code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorearrows.code.te
# x))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaserequires.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasecompatibility.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasefont.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreshade.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreimage.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreexternal.code.
# tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorelayers.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoretransparency.c
# ode.tex
# (/usr/share/texlive/texmf-dist/tex/latex/sansmathaccent/sansmathaccent.sty
# (/usr/share/texlive/texmf-dist/tex/latex/filehook/filehook.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepatterns.code.
# tex))) (/usr/share/texlive/texmf-dist/tex/latex/pgf/utilities/xxcolor.sty)))
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/atbegshi.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/infwarerr.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetranslator.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ltxcmds.sty
# (/usr/share/texlive/texmf-dist/tex/latex/translator/translator.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/hyperref.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/hobsub-hyperref.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasemisc.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/hobsub-generic.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetwoscreens.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseoverlay.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetitle.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasesection.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseframe.sty
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/auxhook.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/kvoptions.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseverbatim.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseframesize.sty
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/pd1enc.def)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseframecomponents.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasecolor.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasenotes.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetoc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetemplates.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseauxtemplates.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseboxes.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/hyperref.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/url/url.sty)
#
# Package hyperref Message: Stopped early.
#
# ) (/usr/share/texlive/texmf-dist/tex/latex/hyperref/hpdftex.def
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/rerunfilecheck.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaserequires.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasecompatibility.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaselocalstructure.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/enumerate.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasefont.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasenavigation.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/sansmathaccent/sansmathaccent.sty
# (/usr/share/texlive/texmf-dist/tex/latex/filehook/filehook.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetranslator.sty
# (/usr/share/texlive/texmf-dist/tex/latex/translator/translator.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetheorems.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasemisc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetwoscreens.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseoverlay.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetitle.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasesection.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasethemes.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseframe.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerthemedefault.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerfontthemedefault.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamercolorthemedefault.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseverbatim.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseframesize.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseframecomponents.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerinnerthemedefault.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasecolor.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasenotes.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetoc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetemplates.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseauxtemplates.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaseboxes.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbaselocalstructure.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/enumerate.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasenavigation.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasetheorems.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerbasethemes.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerthemedefault.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerfontthemedefault.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamercolorthemedefault.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerouterthemedefault.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerinnerthemedefault.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerthemeBerlin.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerouterthememiniframes.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamercolorthemewhale.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamercolorthemeorchid.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerinnerthemerectangles.sty)
# )
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerfontthemestructurebold.st
# y) (/usr/share/texlive/texmf-dist/tex/generic/babel/babel.sty
# (/usr/share/texlive/texmf-dist/tex/generic/babel/switch.def)
# (/usr/share/texlive/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/share/texlive/texmf-dist/tex/generic/babel/babel.def)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerouterthemedefault.sty
# (/usr/share/texlive/texmf-dist/tex/generic/babel/txtbabel.def))))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/utf8x.def))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerthemeBerlin.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerouterthememiniframes.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucs.sty)
#
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-global.def(/usr/share/texlive/texmf-dist/tex/latex/beamer/beamercolorthemewhale.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamercolorthemeorchid.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerinnerthemerectangles.sty))
# )
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty
# (/usr/share/texlive/texmf-dist/tex/latex/beamer/beamerfontthemestructurebold.st
# y) (/usr/share/texlive/texmf-dist/tex/generic/babel/babel.sty
# (/usr/share/texlive/texmf-dist/tex/generic/babel/switch.def)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/chemfig/chemfig.sty
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/frontendlayer/tikz.sty
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/basiclayer/pgf.sty
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/modules/pgfmoduleshapes.code.tex
#
# (/usr/share/texlive/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/share/texlive/texmf-dist/tex/generic/babel/babel.def) (/usr/share/texlive/texmf-dist/tex/generic/pgf/modules/pgfmoduleplot.code.tex
#
# (/usr/share/texlive/texmf-dist/tex/generic/babel/txtbabel.def))
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/compatibility/pgfcomp-version-0-65
# .sty))

# %% [markdown]
# ## 3) Export all tunings:

# %%
model_name_format = 'data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose.model_v20.electron{op}.et%d_eta%d'
config_name_format = 'ElectronRinger{op}TriggerConfig.conf'
for idx, op in enumerate(['Tight','Medium','Loose','VeryLoose']):
    ct.export(best_models, 
              model_name_format.format(op=op), 
              config_name_format.format(op=op), 
              references[idx], 
              to_onnx='new')
# Out:
# WARNING:tensorflow:From /home/lbarranunes/.local/lib/python3.6/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-11 09:19:07,412 | Py.fit_table                            INFO Export all tuning configuration to ElectronRingerTightTriggerConfig.conf.
# 2022-07-11 09:19:13,266 | Py.fit_table                            INFO Export all tuning configuration to ElectronRingerMediumTriggerConfig.conf.
# 2022-07-11 09:19:19,413 | Py.fit_table                            INFO Export all tuning configuration to ElectronRingerLooseTriggerConfig.conf.
# 2022-07-11 09:19:25,500 | Py.fit_table                            INFO Export all tuning configuration to ElectronRingerVeryLooseTriggerConfig.conf.
# 2022-07-11 09:19:01.233415: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:01.233593: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:01.240274: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:01.240304: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.003ms.
# 2022-07-11 09:19:01.240309: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:01.285945: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:01.286056: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:01.294095: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:01.294121: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.495ms.
# 2022-07-11 09:19:01.294126: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.026ms.
# 2022-07-11 09:19:01.294130: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.512ms.
# 2022-07-11 09:19:01.294134: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.019ms.
# 2022-07-11 09:19:01.472412: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:01.472512: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:01.476542: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:01.476569: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:01.476574: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:01.514739: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:01.514837: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:01.521727: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:01.521752: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.443ms.
# 2022-07-11 09:19:01.521756: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.024ms.
# 2022-07-11 09:19:01.521760: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.476ms.
# 2022-07-11 09:19:01.521764: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.026ms.
# 2022-07-11 09:19:01.711040: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:01.711142: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:01.715164: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:01.715192: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:01.715196: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:01.770424: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:01.770530: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:01.777454: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:01.777483: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.462ms.
# 2022-07-11 09:19:01.777487: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.024ms.
# 2022-07-11 09:19:01.777491: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.476ms.
# 2022-07-11 09:19:01.777495: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:01.965774: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:01.965884: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:01.970223: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:01.970252: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:01.970256: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:02.008043: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.008154: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.014982: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.015005: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.43ms.
# 2022-07-11 09:19:02.015010: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:02.015015: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.474ms.
# 2022-07-11 09:19:02.015018: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.016ms.
# 2022-07-11 09:19:02.197923: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.198028: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.202253: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.202280: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:02.202284: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:02.243025: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.243131: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.250051: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.250077: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.427ms.
# 2022-07-11 09:19:02.250082: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.021ms.
# 2022-07-11 09:19:02.250086: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.47ms.
# 2022-07-11 09:19:02.250090: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:02.423253: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.423374: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.427382: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.427410: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:02.427415: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:02.464882: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.464981: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.471776: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.471803: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.426ms.
# 2022-07-11 09:19:02.471807: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.045ms.
# 2022-07-11 09:19:02.471811: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.531ms.
# 2022-07-11 09:19:02.471815: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.018ms.
# 2022-07-11 09:19:02.648354: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.648457: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.653040: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.653069: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:02.653073: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:02.709403: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.709495: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.716712: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.716739: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.517ms.
# 2022-07-11 09:19:02.716744: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.026ms.
# 2022-07-11 09:19:02.716748: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.508ms.
# 2022-07-11 09:19:02.716751: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.019ms.
# 2022-07-11 09:19:02.897847: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.897960: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.902221: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.902251: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:02.902255: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:02.940986: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:02.941088: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:02.948330: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:02.948354: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.563ms.
# 2022-07-11 09:19:02.948359: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.025ms.
# 2022-07-11 09:19:02.948362: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.53ms.
# 2022-07-11 09:19:02.948366: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.019ms.
# 2022-07-11 09:19:03.124335: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.124437: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.128455: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.128482: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:03.128487: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:03.169761: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.169866: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.176990: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.177017: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.607ms.
# 2022-07-11 09:19:03.177021: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:03.177025: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.49ms.
# 2022-07-11 09:19:03.177028: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.018ms.
# 2022-07-11 09:19:03.355338: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.355445: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.359479: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.359506: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:03.359511: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:03.397675: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.397776: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.404700: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.404724: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.482ms.
# 2022-07-11 09:19:03.404729: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.024ms.
# 2022-07-11 09:19:03.404733: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.505ms.
# 2022-07-11 09:19:03.404736: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:03.599760: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.599895: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.604111: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.604141: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:03.604146: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:03.646407: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.646499: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.653538: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.653567: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.462ms.
# 2022-07-11 09:19:03.653572: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.024ms.
# 2022-07-11 09:19:03.653575: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.476ms.
# 2022-07-11 09:19:03.653579: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:03.842509: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.842624: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.846949: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.846980: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.003ms.
# 2022-07-11 09:19:03.846984: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:03.902373: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:03.902460: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:03.909450: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:03.909477: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.464ms.
# 2022-07-11 09:19:03.909482: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.025ms.
# 2022-07-11 09:19:03.909486: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.481ms.
# 2022-07-11 09:19:03.909489: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:04.083988: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.084103: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.088089: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.088118: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:04.088123: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:04.129497: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.129587: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.136642: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.136669: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.472ms.
# 2022-07-11 09:19:04.136674: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.024ms.
# 2022-07-11 09:19:04.136678: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.528ms.
# 2022-07-11 09:19:04.136682: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.016ms.
# 2022-07-11 09:19:04.327249: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.327363: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.331463: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.331491: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:04.331496: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:04.370063: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.370149: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.377090: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.377115: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.503ms.
# 2022-07-11 09:19:04.377120: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:04.377124: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.475ms.
# 2022-07-11 09:19:04.377128: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.018ms.
# 2022-07-11 09:19:04.552049: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.552180: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.556236: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.556265: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:04.556270: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:04.609819: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.609908: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.617068: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.617097: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.605ms.
# 2022-07-11 09:19:04.617101: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:04.617105: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.478ms.
# 2022-07-11 09:19:04.617109: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:04.799281: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.799385: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.803405: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.803434: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:04.803438: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:04.858046: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:04.858134: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:04.865329: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:04.865357: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.467ms.
# 2022-07-11 09:19:04.865361: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.027ms.
# 2022-07-11 09:19:04.865365: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.474ms.
# 2022-07-11 09:19:04.865369: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.016ms.
# 2022-07-11 09:19:05.041628: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.041733: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.045774: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.045804: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:05.045809: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:05.088249: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.088351: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.095495: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.095521: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.519ms.
# 2022-07-11 09:19:05.095526: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.028ms.
# 2022-07-11 09:19:05.095530: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.56ms.
# 2022-07-11 09:19:05.095534: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.019ms.
# 2022-07-11 09:19:05.285132: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.285262: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.289659: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.289688: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:05.289692: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:05.328944: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.329041: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.336406: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.336431: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.571ms.
# 2022-07-11 09:19:05.336435: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.029ms.
# 2022-07-11 09:19:05.336439: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.533ms.
# 2022-07-11 09:19:05.336442: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.019ms.
# 2022-07-11 09:19:05.523866: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.523977: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.528244: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.528272: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:05.528277: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:05.570841: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.570957: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.578071: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.578099: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.54ms.
# 2022-07-11 09:19:05.578104: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.025ms.
# 2022-07-11 09:19:05.578108: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.49ms.
# 2022-07-11 09:19:05.578111: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:05.764082: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.764191: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.768450: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.768478: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:05.768482: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:05.807870: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:05.807956: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:05.814866: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:05.814908: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.429ms.
# 2022-07-11 09:19:05.814913: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.025ms.
# 2022-07-11 09:19:05.814917: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.475ms.
# 2022-07-11 09:19:05.814921: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.029ms.
# 2022-07-11 09:19:06.013149: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:06.013271: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:06.017436: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:06.017465: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:06.017469: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:06.059581: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:06.059673: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:06.066633: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:06.066660: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.433ms.
# 2022-07-11 09:19:06.066664: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:06.066669: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.478ms.
# 2022-07-11 09:19:06.066673: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:06.475018: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:06.475133: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:06.477613: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:06.477635: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:06.477651: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:06.529545: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:06.529629: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:06.534508: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:06.534529: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.448ms.
# 2022-07-11 09:19:06.534533: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.03ms.
# 2022-07-11 09:19:06.534537: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.479ms.
# 2022-07-11 09:19:06.534541: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.02ms.
# 2022-07-11 09:19:06.713234: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:06.713350: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:06.715873: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:06.715896: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:06.715901: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:06.754265: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:06.754367: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:06.759137: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:06.759156: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.421ms.
# 2022-07-11 09:19:06.759161: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.025ms.
# 2022-07-11 09:19:06.759165: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.475ms.
# 2022-07-11 09:19:06.759168: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.021ms.
# 2022-07-11 09:19:06.957476: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:06.957616: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:06.959955: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:06.959978: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:06.959982: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:07.015889: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:07.015999: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:07.020844: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:07.020865: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.483ms.
# 2022-07-11 09:19:07.020869: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.029ms.
# 2022-07-11 09:19:07.020873: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.507ms.
# 2022-07-11 09:19:07.020877: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.018ms.
# 2022-07-11 09:19:07.200755: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:07.200871: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:07.203284: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:07.203306: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:07.203311: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:07.256002: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:07.256107: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:07.260941: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:07.260960: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.467ms.
# 2022-07-11 09:19:07.260965: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.026ms.
# 2022-07-11 09:19:07.260968: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.5ms.
# 2022-07-11 09:19:07.260972: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:07.456171: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:07.456279: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:07.458604: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:07.458626: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:07.458630: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:07.496801: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:07.496884: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:07.501674: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:07.501694: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.446ms.
# 2022-07-11 09:19:07.501699: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.024ms.
# 2022-07-11 09:19:07.501702: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.481ms.
# 2022-07-11 09:19:07.501706: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:07.678839: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:07.678971: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:07.681310: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:07.681332: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:07.681336: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:07.719330: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:07.719416: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# ...
# 2022-07-11 09:19:23.207815: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.207928: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.210355: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.210378: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:23.210383: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:23.251044: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.251135: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.255927: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.255949: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.475ms.
# 2022-07-11 09:19:23.255954: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.025ms.
# 2022-07-11 09:19:23.255958: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.526ms.
# 2022-07-11 09:19:23.255962: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.019ms.
# 2022-07-11 09:19:23.444037: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.444149: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.446474: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.446495: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:23.446500: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:23.483747: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.483835: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.488624: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.488643: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.532ms.
# 2022-07-11 09:19:23.488647: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:23.488651: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.519ms.
# 2022-07-11 09:19:23.488655: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:23.661836: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.661952: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.664230: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.664251: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:23.664255: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:23.718334: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.718422: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.723167: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.723187: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.406ms.
# 2022-07-11 09:19:23.723192: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:23.723196: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.474ms.
# 2022-07-11 09:19:23.723200: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.028ms.
# 2022-07-11 09:19:23.909704: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.909819: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.912329: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.912355: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:23.912359: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:23.963550: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:23.963642: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:23.969085: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:23.969105: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.711ms.
# 2022-07-11 09:19:23.969109: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.025ms.
# 2022-07-11 09:19:23.969113: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.48ms.
# 2022-07-11 09:19:23.969117: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:24.159812: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:24.159937: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:24.162225: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:24.162247: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:24.162252: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:24.216482: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:24.216570: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:24.221568: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:24.221590: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.614ms.
# 2022-07-11 09:19:24.221595: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.023ms.
# 2022-07-11 09:19:24.221598: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.484ms.
# 2022-07-11 09:19:24.221602: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.027ms.
# 2022-07-11 09:19:24.412434: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:24.412540: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:24.414873: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:24.414893: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:24.414898: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:24.466727: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:24.466814: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:24.471663: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:24.471682: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.44ms.
# 2022-07-11 09:19:24.471687: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.026ms.
# 2022-07-11 09:19:24.471691: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.551ms.
# 2022-07-11 09:19:24.471695: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.019ms.
# 2022-07-11 09:19:24.841497: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:24.841613: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:24.844104: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:24.844127: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:24.844132: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-07-11 09:19:24.885792: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:24.885900: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:24.890874: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:24.890911: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.475ms.
# 2022-07-11 09:19:24.890916: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.029ms.
# 2022-07-11 09:19:24.890920: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.485ms.
# 2022-07-11 09:19:24.890924: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.018ms.
# 2022-07-11 09:19:25.071569: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:25.071679: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:25.074016: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:25.074039: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:25.074044: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:25.129424: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:25.129510: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:25.134334: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:25.134354: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.439ms.
# 2022-07-11 09:19:25.134359: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.027ms.
# 2022-07-11 09:19:25.134363: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.483ms.
# 2022-07-11 09:19:25.134366: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.017ms.
# 2022-07-11 09:19:25.315306: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:25.315435: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:25.317834: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:25.317857: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-07-11 09:19:25.317862: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-07-11 09:19:25.356780: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-07-11 09:19:25.356879: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-07-11 09:19:25.361690: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2022-07-11 09:19:25.361710: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (-8), 34 edges (-8), time = 1.444ms.
# 2022-07-11 09:19:25.361714: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.024ms.
# 2022-07-11 09:19:25.361718: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   constant_folding: Graph size after: 34 nodes (0), 34 edges (0), time = 0.483ms.
# 2022-07-11 09:19:25.361722: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.018ms.

# %%
best_models[4][0].keys()
# Out:
# dict_keys(['model', 'etBin', 'etaBin', 'etBinIdx', 'etaBinIdx', 'history', 'thresholds'])

# %%
best_models[4][0]['thresholds']
# Out:
# {'tight_cutbased': {'offset': 0.9662279213694993,
#   'slope': -0.00523850155646967,
#   'threshold': 0.7740635208408329,
#   'reference_pd': 0.9962596734150866,
#   'reference_fa': 0.2026224674081667,
#   'figures': ['/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_signal_tight_cutbased_et4_eta0.pdf',
#    '/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_background_tight_cutbased_et4_eta0.pdf']},
#  'medium_cutbased': {'offset': 0.812318985053928,
#   'slope': -0.006156220297094779,
#   'threshold': 0.5900321865179448,
#   'reference_pd': 0.9972538224150611,
#   'reference_fa': 0.24551311843839332,
#   'figures': ['/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_signal_medium_cutbased_et4_eta0.pdf',
#    '/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_background_medium_cutbased_et4_eta0.pdf']},
#  'loose_cutbased': {'offset': -0.6708003279245514,
#   'slope': -0.017530105702503143,
#   'threshold': -1.2676791235171778,
#   'reference_pd': 0.9997055719597882,
#   'reference_fa': 0.9137504854554368,
#   'figures': ['/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_signal_loose_cutbased_et4_eta0.pdf',
#    '/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_background_loose_cutbased_et4_eta0.pdf']},
#  'vloose_cutbased': {'offset': -0.9167556240078839,
#   'slope': -0.017809886390124537,
#   'threshold': -1.5194292054039986,
#   'reference_pd': 0.9997594898519258,
#   'reference_fa': 0.9236490013942917,
#   'figures': ['/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_signal_vloose_cutbased_et4_eta0.pdf',
#    '/home/lbarranunes/workspace/ringer_tunings/versions/v20/r0/corrections/correction_v20_data17_13TeV_EGAM1_probes_lhmedium_EGAM7_vetolhvloose/th2_background_vloose_cutbased_et4_eta0.pdf']}}
