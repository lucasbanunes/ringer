# %%
import os
import sys
import numpy as np
import pandas as pd

home_path = os.path.expanduser("~")
ringer_path = os.path.join(home_path, "workspace", "ringer")
sys.path.append(ringer_path)
from ringer.data import NamedDatasetLoader

# %%
load_cols = ["id", "region_id"] + [f"L2Calo_ring_{i}" for i in range(99)]
dataset_loader = NamedDatasetLoader("2017_medium", test=True)

# %%
data_df = dataset_loader.load_data_df(load_cols)
data_df
# Out:
#                id  region_id  L2Calo_ring_0  L2Calo_ring_1  L2Calo_ring_2  \
# 0        27639419          7     946.455200     297.285675    -162.731384
# 1        27639420          5    1155.483643     231.537582     841.838196
# 2        27639421          8    2306.196045     123.935341     -92.987045
# 3        27639422         18    1661.695190     311.053619    -193.597885
# 4        27639423         17     716.282349     572.603027      24.837866
# ...           ...        ...            ...            ...            ...
# 5469192  33108611    5469195    5393.083984    6293.918457    2142.531982
# 5469193  33108612    5469186    1886.167847    2201.420166    1226.021851
# 5469194  33108613    5469191    4935.441406    3388.302002    1608.521729
# 5469195  33108614    5469192    2346.245361    5741.150879    3533.290771
# 5469196  33108615    5469196    5280.234375    7856.251953    1512.040405
#
#          L2Calo_ring_3  L2Calo_ring_4  L2Calo_ring_5  L2Calo_ring_6  \
# ...
